# %%
#mount the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#To Download the github repo to google drive
# !git clone https://gitfront.io/r/user-8948418/7v8eAoZ77xBD/KPTPACE-DLCV-Workshop.gitfront.git /content/gdrive/MyDrive/DLCV_workshop
# Out:
# Cloning into '/content/gdrive/MyDrive/DLCV_workshop'...
# Checking out files: 100% (163/163), done.
